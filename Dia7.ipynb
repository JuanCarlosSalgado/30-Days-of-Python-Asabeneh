# %% [markdown]
# # sets
# it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
# A = {19, 22, 24, 20, 25, 26}
# B = {19, 22, 20, 25, 26, 24, 28, 27}
# age = [22, 19, 24, 25, 26, 24, 25, 24]

# %%
it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]

# %% [markdown]
# Find the length of the set it_companies

# %%
print(len(it_companies))
# Out:
# 7

# %% [markdown]
# Add 'Twitter' to it_companies

# %%
it_companies.add("Twitter")
print(it_companies)
# Out:
# {'Microsoft', 'Apple', 'Facebook', 'IBM', 'Amazon', 'Twitter', 'Oracle', 'Google'}

# %% [markdown]
# Insert multiple IT companies at once to the set it_companies

# %%
it_companies.update(["Tesla","IA Interactive"])
print(it_companies)
# Out:
# {'Microsoft', 'IA Interactive', 'Tesla', 'Apple', 'Facebook', 'IBM', 'Amazon', 'Twitter', 'Oracle', 'Google'}

# %% [markdown]
# Remove one of the companies from the set it_companies

# %%
it_companies.remove("Tesla")
print(it_companies)
# Out:
# {'Microsoft', 'IA Interactive', 'Apple', 'Facebook', 'IBM', 'Amazon', 'Twitter', 'Oracle', 'Google'}

# %% [markdown]
# What is the difference between remove and discard?
#
# Remove returns errors if doesnt found the target

# %% [markdown]
# Join A and B

# %%
C = A.union(B)

# %% [markdown]
# Find A intersection B

# %%
A.intersection(B)
# Out:
# {19, 20, 22, 24, 25, 26}

# %% [markdown]
# Is A subset of B

# %%
A.issubset(B)
# Out:
# True

# %%
B.issubset(A)
# Out:
# False

# %% [markdown]
# Are A and B disjoint sets

# %%
A.isdisjoint(B)
# Out:
# False

# %% [markdown]
# Join A with B and B with A

# %%
D = A.union(B)
E = B.union(A)
print(D,E)
# Out:
# {19, 20, 22, 24, 25, 26, 27, 28} {19, 20, 22, 24, 25, 26, 27, 28}

# %% [markdown]
# What is the symmetric difference between A and B

# %%
B.symmetric_difference(A)
# Out:
# {27, 28}

# %% [markdown]
# Delete the sets completely

# %%
del A
del B

# %% [markdown]
# Convert the ages to a set and compare the length of the list and the set, which one is bigger?

# %%
age = set(age)
print(age)
# Out:
# {19, 22, 24, 25, 26}

# %% [markdown]
# Explain the difference between the following data types: string, list, tuple and set

# %% [markdown]
# String = "words"
# list = [can, modify]
# tuple = (cannot, modify)
# set = {unions, intersections and so...}

# %% [markdown]
# I am a teacher and I love to inspire and teach people. How many unique words have been used in the sentence? Use the split methods and set to get the unique words.

# %%
strr = "I am a teacher and I love to inspire and teach people"
x = strr.split()
print(x)
print(len(x))
# Out:
# ['I', 'am', 'a', 'teacher', 'and', 'I', 'love', 'to', 'inspire', 'and', 'teach', 'people']
# 12
