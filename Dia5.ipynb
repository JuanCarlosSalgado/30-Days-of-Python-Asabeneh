# %% [markdown]
# Declare an empty list

# %%
l = []
print(type(l))
# Out:
# <class 'list'>

# %% [markdown]
# Declare a list with more than 5 items

# %%
l1 = [1,2,3,4,5]

# %% [markdown]
# Find the length of your list

# %%
print(len(l1))
# Out:
# 5

# %% [markdown]
# Get the first item, the middle item and the last item of the list

# %%
print(l1[0], l1[4])
# Out:
# 1 5

# %% [markdown]
# Declare a list called mixed_data_types, put your(name, age, height, marital status, address)

# %%
mixed_data_types = [26,1.90,"Soltero","Morelia"]

# %% [markdown]
# Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.

# %%
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle","Amazon"]

# %% [markdown]
# Print the list using print()

# %%
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# Print the number of companies in the list

# %%
print(len(it_companies))
# Out:
# 7

# %% [markdown]
# Print the first, middle and last company

# %%
print(it_companies[0], it_companies[3],it_companies[6])
# Out:
# Facebook Apple Amazon

# %% [markdown]
# Print the list after modifying one of the companies

# %%
it_companies[0] = "tesla"
print(it_companies)
# Out:
# ['tesla', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# Add an IT company to it_companies

# %%
it_companies.append("Facebook")
print(it_companies)
# Out:
# ['tesla', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Facebook']

# %% [markdown]
# Insert an IT company in the middle of the companies list

# %%
it_companies.insert(4,"EDx")

# %% [markdown]
# Change one of the it_companies names to uppercase (IBM excluded!)

# %%
it_companies[1] = "GOOGLE"
print(it_companies)
# Out:
# ['tesla', 'GOOGLE', 'Microsoft', 'Apple', 'EDx', 'IBM', 'Oracle', 'Amazon', 'Facebook']

# %% [markdown]
# Join the it_companies with a string '#;  '

# %%
it_companies.extend("#;")

# %% [markdown]
# Check if a certain company exists in the it_companies list.

# %%
print("IBM" in it_companies)
# Out:
# True

# %% [markdown]
# Sort the list using sort() method

# %%
it_companies.sort()
print(it_companies)
# Out:
# ['#', ';', 'Amazon', 'Apple', 'EDx', 'Facebook', 'GOOGLE', 'IBM', 'Microsoft', 'Oracle', 'tesla']

# %% [markdown]
# Reverse the list in descending order using reverse() method

# %%
it_companies.sort(reverse = True)
print(it_companies)
# Out:
# ['tesla', 'Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'EDx', 'Apple', 'Amazon', ';', '#']

# %% [markdown]
# Slice out the first 3 companies from the list

# %%
print(it_companies[0:3])
# Out:
# ['tesla', 'Oracle', 'Microsoft']

# %% [markdown]
# Slice out the last 3 companies from the list

# %%
print(it_companies[-3:])
# Out:
# ['Amazon', ';', '#']

# %% [markdown]
# Slice out the middle IT company or companies from the list

# %%
print(it_companies[4:7])
# Out:
# ['GOOGLE', 'Facebook', 'EDx']

# %% [markdown]
# Remove the first IT company from the list

# %%
del it_companies[0]
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'EDx', 'Apple', 'Amazon', ';', '#']

# %% [markdown]
# Remove the middle IT company or companies from the list

# %%
del it_companies[5]
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'Apple', 'Amazon', ';', '#']

# %% [markdown]
# Remove the last IT company from the list

# %%
del it_companies[8]
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'Apple', 'Amazon', ';']

# %% [markdown]
# Remove all IT companies from the list

# %%
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
it_companies.pop()
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'Apple', 'Amazon']
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook', 'Apple']
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE', 'Facebook']
# ['Oracle', 'Microsoft', 'IBM', 'GOOGLE']
# ['Oracle', 'Microsoft', 'IBM']
# ['Oracle', 'Microsoft']
# ['Oracle']
# []

# %% [markdown]
# Destroy the IT companies list

# %%
del it_companies

# %% [markdown]
# Join the following lists:
# front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
# back_end = ['Node','Express', 'MongoDB']

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']
Full_stack = front_end + back_end
print(Full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %% [markdown]
# After joining the lists in question 26. Copy the joined list and assign it to a variable full_stack. Then insert Python and SQL after Redux.

# %%
Full_stack.insert(5,"Python")
print(Full_stack)
Full_stack.insert(6,"SQL")
print(Full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Python', 'Node', 'Express', 'MongoDB']
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Python', 'SQL', 'Node', 'Express', 'MongoDB']
