# %% [markdown]
# Create an empty dictionary called dog

# %%
dog = {}
print(type(dog))
# Out:
# <class 'dict'>

# %% [markdown]
# Add name, color, breed, legs, age to the dog dictionary

# %%
dog["Name"] = "Godofredo"
dog["Color"] = "Rainbow"
dog["Breed"] = "Hus"
dog["Legs"] = "2 and a half"
dog["age"] = "7"

# %% [markdown]
# Create a student dictionary and add first_name, last_name, gender, age, marital status, skills, country, city and address as keys for the dictionary

# %%
Student = {
    "First_name" : "Olaf",
    "Last_Name" : "Brand",
    "Gender" : "Male",
    "Age" : "21",
    "Martial Status" : "Single",
    "Skills" : ["none","Deutsch"],
    "Country" : "Road",
    "City" : "Detroit rock",
    "Address" : {
        "Av" : "Madero",
        "Colonia" : "Independencia"
    }
}

# %% [markdown]
# Get the length of the student dictionary

# %%
print(len(Student))
# Out:
# 9

# %% [markdown]
# Get the value of skills and check the data type, it should be a list

# %%
print(Student.get("Skills"))
print(type(Student.get("Skills")))
# Out:
# ['none', 'Deutsch']
# <class 'list'>

# %% [markdown]
# Modify the skills values by adding one or two skills

# %%
Student["Skills"].append("breathe")
Student["Skills"].append("Dance")
print(Student.get("Skills"))
# Out:
# ['none', 'Deutsch', 'breathe', 'Dance']

# %% [markdown]
# Get the dictionary keys as a list

# %%
keys = Student.keys()
print(keys)
# Out:
# dict_keys(['First_name', 'Last_Name', 'Gender', 'Age', 'Martial Status', 'Skills', 'Country', 'City', 'Address'])

# %% [markdown]
# Get the dictionary values as a list

# %%
values = Student.values()
print(values)
# Out:
# dict_values(['Olaf', 'Brand', 'Male', '21', 'Single', ['none', 'Deutsch', 'breathe', 'Dance'], 'Road', 'Detroit rock', {'Av': 'Madero', 'Colonia': 'Independencia'}])

# %% [markdown]
# Change the dictionary to a list of tuples using items() method

# %%
print(Student.items())
# Out:
# dict_items([('First_name', 'Olaf'), ('Last_Name', 'Brand'), ('Gender', 'Male'), ('Age', '21'), ('Martial Status', 'Single'), ('Skills', ['none', 'Deutsch', 'breathe', 'Dance']), ('Country', 'Road'), ('City', 'Detroit rock'), ('Address', {'Av': 'Madero', 'Colonia': 'Independencia'})])

# %% [markdown]
# Delete one of the items in the dictionary

# %%
del Student["Skills"]
print(Student)
# Out:
# {'First_name': 'Olaf', 'Last_Name': 'Brand', 'Gender': 'Male', 'Age': '21', 'Martial Status': 'Single', 'Country': 'Road', 'City': 'Detroit rock', 'Address': {'Av': 'Madero', 'Colonia': 'Independencia'}}

# %% [markdown]
# Delete one of the dictionaries

# %%
del Student
